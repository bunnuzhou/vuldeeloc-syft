# %%
#PART 1: Launch a Duet Server and Connect
import syft as sy
duet = sy.launch_duet()
# Out:
# 🎤  🎸  ♪♪♪ Starting Duet ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently in beta.
# ♫♫♫ >             Use at your own risk.
# ♫♫♫ >
# ♫♫♫ > Punching through firewall to OpenGrid Network Node at:
# ♫♫♫ > http://ec2-18-216-8-163.us-east-2.compute.amazonaws.com:5000
# ♫♫♫ >
# ♫♫♫ > ...waiting for response from OpenGrid Network... DONE!
# ♫♫♫ >
# ♫♫♫ > STEP 1: Send the following code to your Duet Partner!
#
# import syft as sy
# duet = sy.duet("797681c9ce754394a5ab2ef134956007")
#
# ♫♫♫ > STEP 2: Running the code above will print out a 'Client ID'.
# ♫♫♫ >         Have your duet partner send it to you and enter it below!
#
# ♫♫♫ > Duet Partner's Client ID: 03985a02641c1833936826cd80109480
# ♫♫♫ > Connecting...
# ♫♫♫ > ...using a running event loop...
#
# ♫♫♫ > CONNECTED!
#
# ♫♫♫ > DUET LIVE STATUS  *  Objects: 7  Requests: 0   Messages: 2986
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ♫♫♫ > DUET LIVE STATUS  -  Objects: 7  Requests: 0   Messages: 2986

# %%
#PART 2: Add Request Handlers
duet.requests.pandas
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
duet.requests.add_handler(
    name="cuda_is_available",
    action="accept"
)

duet.requests.add_handler(
    name="loss",
    action="deny",
    timeout_secs=-1,  # no timeout
    print_local=True  # print the result in your notebook
)

duet.requests.add_handler(
    name="train_size",
    action="accept"
)

duet.requests.add_handler(
    name="inference",
    action="accept"
)

duet.requests.add_handler(
    name="model_download",
    action="accept"
)

# %%
duet.requests.handlers
# Out:
# [{'action': 'accept',
#   'print_local': False,
#   'log_local': False,
#   'name': 'cuda_is_available',
#   'timeout_secs': -1,
#   'created_time': 1616739200.0},
#  {'action': 'deny',
#   'print_local': True,
#   'log_local': False,
#   'name': 'loss',
#   'timeout_secs': -1,
#   'created_time': 1616739200.0},
#  {'action': 'accept',
#   'print_local': False,
#   'log_local': False,
#   'name': 'train_size',
#   'timeout_secs': -1,
#   'created_time': 1616739200.0},
#  {'action': 'accept',
#   'print_local': False,
#   'log_local': False,
#   'name': 'inference',
#   'timeout_secs': -1,
#   'created_time': 1616739200.0},
#  {'action': 'accept',
#   'print_local': False,
#   'log_local': False,
#   'name': 'model_download',
#   'timeout_secs': -1,
#   'created_time': 1616739200.0}]
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...d a 'List'",)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...d a 'List'",)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 135, in execute_action
#     result = method(resolved_self.data, *upcasted_args, **upcasted_kwargs)
# TypeError: descriptor '__getitem__' requires a 'torch._C._TensorBase' object but received a 'List'
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...373a22f202>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...373a22f202>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 39837768079c4c4a8fff42373a22f202>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...02a710f8c3>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...02a710f8c3>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 03df6f3d3f084c6d82e84302a710f8c3>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...fd834c97f8>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...fd834c97f8>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 3db0d08d87e248ff890fd2fd834c97f8>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...be36b56aee>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...be36b56aee>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 3087f451ad5c4409888ccebe36b56aee>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...rmissions'",)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...rmissions'",)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/function_or_constructor_action.py", line 90, in execute_action
#     result_read_permissions, r_arg.read_permissions
# AttributeError: 'NoneType' object has no attribute 'read_permissions'
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...f65bb92b68>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...f65bb92b68>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 7de31554c0d04b5dac33f0f65bb92b68>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...7e147fd475>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...7e147fd475>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 0081cf43735e4174888fae7e147fd475>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...ec08da04dd>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...ec08da04dd>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: c77c858b3b2a4017aafca1ec08da04dd>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...d a 'List'",)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...d a 'List'",)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
# ...
# AttributeError: 'NoneType' object has no attribute 'read_permissions'
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...a964972619>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...a964972619>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 4c5bbfaa96554bf9a1c397a964972619>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...674691a5b2>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...674691a5b2>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 024bea2d00114d7db2eaa2674691a5b2>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...b7b5faae07>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...b7b5faae07>,)>) at /home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/asyncio/tasks.py", line 180, in _step
#     result = coro.send(None)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 208, in on_message
#     await self.consumer(msg=message)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 933, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 384, in consumer
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 368, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 428, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/grid/connections/webrtc.py", line 421, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 425, in recv_immediate_msg_without_reply
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 397, in recv_immediate_msg_without_reply
#     msg=msg, router=self.immediate_msg_without_reply_router
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/node.py", line 482, in process_message
#     verify_key=msg.verify_key,
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/node/common/action/run_class_method_action.py", line 106, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/decorators/typecheck.py", line 110, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/typeguard/__init__.py", line 912, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 73, in __getitem__
#     raise e
#   File "/home/chxhe/miniconda3/envs/vul/lib/python3.6/site-packages/syft/core/store/store_memory.py", line 70, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 5389c6af304b4419bfd914b7b5faae07>
